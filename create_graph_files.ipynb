# %%
from source.structure_modeling import graphUsingMnearestNeighbors
from source.utils import load_data_df
import pandas as pd
import networkx as nx

# %% [markdown]
# # BASIC kNN method

# %% [markdown]
# ### Raw audio

# %%
raw_audio_df = load_data_df("data/raw_audio/")

# %%
raw_audio_G = graphUsingMnearestNeighbors(raw_audio_df, M=5)

# %%
nx.write_adjlist(raw_audio_G, "graphs/raw_audio_kNN.adjlist")

# %% [markdown]
# ### Spectrogram 2

# %%
spectr2_df = load_data_df("data/spectrogram2/")

# %%
spect2_G = graphUsingMnearestNeighbors(spectr2_df, M=5)

# %%
nx.write_adjlist(spect2_G, "graphs/spectr2_kNN.adjlist")

# %% [markdown]
# ### Spectrogram 3

# %%
spectr3_df = load_data_df("data/spectrogram3/")

# %%
spectr3_G = graphUsingMnearestNeighbors(spectr3_df, M=5)

# %%
nx.draw(spectr3_G, node_size=10, node_color=labels_to_numbers(labels))

# %%
nx.is_connected(G)
# Out:
# True

# %%
nx.write_adjlist(spectr3_G, "graphs/spectr3_kNN.adjlist")
